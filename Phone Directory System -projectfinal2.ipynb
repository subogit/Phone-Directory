# %%
                                 #project phone directory
import time
list_dir= {'aman':9824648122,'amit':9173643122,'vijay':9176643122,'shahid':9657643122,'jaya':9859643122}
# list_dir[name]=c_no
list1=[]
list2=[]

def addContact():
    '''add contacts to the directory'''

    n='Y'
    while n=='Y':
        name= input('Enter your Name ')
        if name in list_dir:
            print('This name already exist .Please change the name ')
            addContact()
        c_no= input('Enter your Contact Number ')
        while c_no.isnumeric()!= True:
            print('Enter Valid Number')
            c_no= input('Enter your Contact Number ')

        list1.append(name)
        list2.append(c_no)
        for x,y in zip(list1,list2):
            list_dir[x]=y
        n= input('Do you want to enter another contact ')  
        while n!='Y' :
            if n=='N':
                break
            print('Sorry !! Wrong Input ')
            n= input('Do you want to enter another contact ')
            
def searchContact():
    '''This function gives contact details of someone user want to see'''
    temp=0                                                                                      #     list_dir={'rama':22222,'sudha':44444,'varshsa':444444,'mahima':3334343,'lalka':5534343,'megha':656546573}
    search_input=input('Please enter the name of a person whose contact you want to see ')
    if search_input.isnumeric():
        for  i in list_dir.keys():
            if search_input in i:
                temp=1
                print(i,list_dir[i])
            else:
                continue
        if temp==0:
            print('Sorry ,there is no contacts with the name you entered')


    for  i in list_dir:
        if search_input in i:
            temp=1
            print(i,list_dir[i])
        else:
            continue
    if temp==0:
        print('Sorry ,there is no contacts with the name you entered')
    
                                                                        # list_dir={'rama':22222,'sudha':44444,'varshsa':444444,'mahima':3334343,'lalka':5534343,'megha':656546573}
def delContact():
    '''It delete the contacts given by the user'''
    del_item=input('Enter the contact name you want to delete ')
    list_dir.pop(del_item)
    print(f'{del_item} has been deleted from contacts ')
    time.sleep(1)
    home()
                                                                                              # list_dir={'rama':22222,'sudha':44444,'varshsa':444444,'mahima':3334343,'lalka':5534343,'megha':656546573}
def updateContact():
    '''It takes the input  and update the contacts '''
    update_name=input('Enter the contact name you want to add ')
    update_no=input('Enter the number ')
    list_dir.update({update_name:update_no})
    print('saved')
    
#     print(list_dir)


def home():
    print((
    '''                           welcome 
    '''))
    time.sleep(1)
    user_input= input(
    '''
            Enter 0 for adding contact
            Enter 1 to view contact
            Enter 2 to update contact 
            Enter 3 to delete contact
                                     ''') 
    x=['1','2','3','0']
    while user_input not in x:
        print("Please Enter Valid Number")
        user_input= input(
        '''
            Enter 0 for adding contact
            Enter 1 to view contact
            Enter 2 to update contact 
            Enter 3 to delete contact
            
            
                                     ''') 
    if user_input=='0':
        addContact()
    elif user_input=='1':
        searchContact()
    elif user_input=='2':
        updateContact()
    elif user_input=='3':
        delContact()
    
        
        
    temp_list= ['1','0']
    main_menu_input= input("Press 0 for Main Menu or 1 for Exit:")
    while main_menu_input not in temp_list:
            main_menu_input= input("Enter Valid Number")
    if main_menu_input=='0':
        home()
    elif main_menu_input =='1':
        print('Have a good Day')
    
        
        

                                                                                        # elif user_input==1:
                                                                                        #     search_name=input("Please enter the name of a person whose contact you want to see")
                                                                                        #     print(list_dir[search_name])
home()
# Out:
#                            welcome
